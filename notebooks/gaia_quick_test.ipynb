# %% [markdown]
# # 🌍 Gaia Core v0.1 Quick Test
# **The Seed of New Earth**

# %%
from gaia.seed_initialization import initialize_seed

# Initialize the Seed
model = initialize_seed()

# %%
from gaia.peii import compute_peii, example_observation

obs = example_observation()
score = compute_peii(obs)
print(f"Current PEII Score: {score:.4f}")
